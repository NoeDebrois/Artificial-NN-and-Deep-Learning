# %% [markdown]
# <a href="https://colab.research.google.com/github/NoeDebrois/Artificial-NN-and-Deep-Learning/blob/main/At_Home_Exercise_Session_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Noé Debrois
#
# ### 📜 TODO Exercise - Exercise Session 1 :
# <img src="https://allisonhorst.github.io/palmerpenguins/reference/figures/lter_penguins.png" width="800">

# %%
# Fix randomness and hide warnings
seed = 42

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

import numpy as np
np.random.seed(seed)

import logging

import random
random.seed(seed)

# Import tensorflow
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.random.set_seed(seed)
print(f"TensorFlow version {tf.__version__}")

# Import other libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', size=14)
# %matplotlib inline
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import train_test_split
# Out:
# TensorFlow version 2.17.0

# %%
# Load Data
os.environ["DATASET_NAME"] = "penguins.csv"
os.environ["DATASET_URL"] = "1qn1P6_KW08wGRfSkTlzBoDCyVb18T3Lk"
if not os.path.exists(os.environ["DATASET_NAME"]):
    print("Downloading data...")
    ! gdown -q ${DATASET_URL}
    print("Download completed")
else:
    print("Data already downloaded. Using cached data...")
dataset = pd.read_csv('penguins.csv')
# Out:
# Data already downloaded. Using cached data...

# %% [markdown]
# ### 🔎 Inspect Data

# %%
# Print the shape of the Penguins dataset
print('Penguins dataset shape', dataset.shape)

# Remove NaN
dataset.dropna(inplace=True)

# Display the first 10 rows of the Iris dataset
dataset.head(10)
# Out:
# Penguins dataset shape (344, 7)
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen            39.1           18.7              181.0
# 1   Adelie  Torgersen            39.5           17.4              186.0
# 2   Adelie  Torgersen            40.3           18.0              195.0
# 4   Adelie  Torgersen            36.7           19.3              193.0
# 5   Adelie  Torgersen            39.3           20.6              190.0
# 6   Adelie  Torgersen            38.9           17.8              181.0
# 7   Adelie  Torgersen            39.2           19.6              195.0
# 12  Adelie  Torgersen            41.1           17.6              182.0
# 13  Adelie  Torgersen            38.6           21.2              191.0
# 14  Adelie  Torgersen            34.6           21.1              198.0
#
#     body_mass_g     sex
# 0        3750.0    MALE
# 1        3800.0  FEMALE
# 2        3250.0  FEMALE
# 4        3450.0  FEMALE
# 5        3650.0    MALE
# 6        3625.0  FEMALE
# 7        4675.0    MALE
# 12       3200.0  FEMALE
# 13       3800.0    MALE
# 14       4400.0    MALE

# %%
# Print the shape of the Penguins dataset
print('Penguins dataset shape', dataset.shape)

# Generate summary statistics for the Penguins dataset
dataset.describe()
# Out:
# Penguins dataset shape (333, 7)
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
# Get the target values from the Penguins dataset
# Here, the target = the species
target = dataset.species
print('Target shape', target.shape)

# Calculate the unique target labels and their counts
unique, count = np.unique(target, return_counts=True)
print('Target labels:', unique)
cpt = 0
for u in unique:
    print(f'Class {u} has {count[cpt]} samples')
    cpt+=1
# Out:
# Target shape (333,)
# Target labels: ['Adelie' 'Chinstrap' 'Gentoo']
# Class Adelie has 146 samples
# Class Chinstrap has 68 samples
# Class Gentoo has 119 samples

# %%
# Copy the Penguins dataset
plot_dataset = dataset.copy()

# Assign target labels to the dataset
plot_dataset["Species"] = target

# Plot using seaborn pairplot
sns.pairplot(plot_dataset, hue="Species", palette="tab10", markers=["o", "s", "D"])
plt.show()

# Clean up by deleting the temporary dataset
del plot_dataset

# %%
# Split the dataset into a combined training and validation set, and a separate test set
X_train_val, X_test, y_train_val, y_test = train_test_split(
    dataset,
    target,
    test_size=20,
    random_state=seed,
    stratify=target
)

# Further split the combined training and validation set into a training set and a validation set
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val,
    y_train_val,
    test_size=20,
    random_state=seed,
    stratify=y_train_val
)

# Print the shapes of the resulting sets
print('Training set shape:\t', X_train.shape, y_train.shape)
print('Validation set shape:\t', X_val.shape, y_val.shape)
print('Test set shape:\t\t', X_test.shape, y_test.shape)
# Out:
# Training set shape:	 (293, 7) (293,)
# Validation set shape:	 (20, 7) (20,)
# Test set shape:		 (20, 7) (20,)

# %% [markdown]
# ### 🔄 Process Data

# %%
# Compute maximum values for each feature
max_df = X_train[["bill_length_mm","bill_depth_mm","flipper_length_mm","body_mass_g"]].max()

# Display maximum values
print('Penguins dataset maximum values')
print(max_df)

# Compute minimum values for each feature
min_df = X_train[["bill_length_mm","bill_depth_mm","flipper_length_mm","body_mass_g"]].min()

# Display minimum values
print('\nPenguins dataset minimum values')
print(min_df)
# Out:
# Penguins dataset maximum values
# bill_length_mm         59.6
# bill_depth_mm          21.2
# flipper_length_mm     231.0
# body_mass_g          6300.0
# dtype: float64
#
# Penguins dataset minimum values
# bill_length_mm         32.1
# bill_depth_mm          13.1
# flipper_length_mm     172.0
# body_mass_g          2700.0
# dtype: float64

# %%
# Normalise training data
X_train = (X_train[["bill_length_mm","bill_depth_mm","flipper_length_mm","body_mass_g"]] - min_df) / (max_df - min_df)

# Normalise validation data
X_val = (X_val[["bill_length_mm","bill_depth_mm","flipper_length_mm","body_mass_g"]] - min_df) / (max_df - min_df)

# Normalise test data
X_test = (X_test[["bill_length_mm","bill_depth_mm","flipper_length_mm","body_mass_g"]] - min_df) / (max_df - min_df)

# %%
# Display summary statistics of the normalised training data
X_train.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      293.000000     293.000000         293.000000   293.000000
# mean         0.432616       0.504108           0.494591     0.421786
# std          0.197361       0.245145           0.238548     0.225843
# min          0.000000       0.000000           0.000000     0.000000
# 25%          0.261818       0.308642           0.305085     0.236111
# 50%          0.436364       0.518519           0.423729     0.375000
# 75%          0.607273       0.691358           0.711864     0.569444
# max          1.000000       1.000000           1.000000     1.000000

# %%
# Preparation of the one-hot encoding : convert the strings 'Adelie', etc. to int :
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder object
encoder = LabelEncoder()

# Fit the encoder on all unique labels
encoder.fit(pd.concat([y_train, y_val, y_test]))

# Transform labels to numerical representation
y_train = encoder.transform(y_train)
y_val = encoder.transform(y_val)
y_test = encoder.transform(y_test)

# Now you can apply one-hot encoding
y_train = tfk.utils.to_categorical(y_train, num_classes=len(unique))
y_val = tfk.utils.to_categorical(y_val, num_classes=len(unique))
y_test = tfk.utils.to_categorical(y_test, num_classes=len(unique))

# Display shapes of the encoded label sets
print('Training set target shape:\t', y_train.shape)
print('Validation set target shape:\t', y_val.shape)
print('Test set target shape:\t\t', y_test.shape)
# Out:
# Training set target shape:	 (293, 3)
# Validation set target shape:	 (20, 3)
# Test set target shape:		 (20, 3)

# %%
# Determine the input shape, corresponding to the number of features
input_shape = X_train.shape[1:]
print(f'Input shape of the network {input_shape}')

# Determine the output shape, corresponding to the number of classes
output_shape = y_train.shape[1]
print(f'Output shape of the network {output_shape}')
# Out:
# Input shape of the network (4,)
# Output shape of the network 3

# %% [markdown]
# ### 🧮 Define Network Parameters

# %%
# Batch size: number of samples processed in each training iteration
batch_size = 16

# Number of epochs: times the entire dataset is passed through the network during training
epochs = 500

# Learning rate: step size for updating the model's weights
learning_rate = 0.001

# %% [markdown]
# ### 🛠️ Build the Model

# %%
def build_model(
    input_shape=input_shape,
    output_shape=output_shape,
    learning_rate=learning_rate,
    seed=seed
):

    # Fix randomness
    tf.random.set_seed(seed)

    # Build the neural network layer by layer
    inputs = tfkl.Input(shape=input_shape, name='Input')

    # Add hidden layer with ReLU activation
    x = tfkl.Dense(units=16, name='Hidden')(inputs)
    x = tfkl.Activation('relu', name='HiddenActivation')(x)

    # Add output layer with softmax activation
    x = tfkl.Dense(units=output_shape, name='Output')(x)
    outputs = tfkl.Activation('softmax', name='Softmax')(x)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=inputs, outputs=outputs, name='FeedforwardNeuralNetwork')

    # Compile the model with loss, optimizer, and metrics
    loss = tfk.losses.CategoricalCrossentropy()
    optimizer = tfk.optimizers.Adam(learning_rate)
    metrics = ['accuracy']
    model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

    # Return the model
    return model

# %%
# Build the model with specified input and output shapes
model = build_model()

# Display a summary of the model architecture
model.summary(expand_nested=True, show_trainable=True)

# Plot the model architecture
tfk.utils.plot_model(model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Model: "FeedforwardNeuralNetwork"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)                        ┃ Output Shape                 ┃       Param # ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ Input (InputLayer)                  │ (None, 4)                    │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ Hidden (Dense)                      │ (None, 16)                   │            80 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ HiddenActivation (Activation)       │ (None, 16)                   │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ Output (Dense)                      │ (None, 3)                    │            51 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ Softmax (Activation)                │ (None, 3)                    │             0 │    -    │
# └─────────────────────────────────────┴──────────────────────────────┴───────────────┴─────────┘
#  Total params: 131 (524.00 B)
#  Trainable params: 131 (524.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 🧠 Train the Model

# %%
# Train the model and store the training history
history = model.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val)
).history

# Calculate the final validation accuracy
final_val_accuracy = round(history['val_accuracy'][-1] * 100, 2)

# Save the trained model to a file with the accuracy included in the filename
model_filename = f'Penguins_Feedforward_{final_val_accuracy}.keras'
model.save(model_filename)

# Delete the model to free up memory resources
del model
# Out:
# Epoch 1/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.3658 - loss: 1.0602 - val_accuracy: 0.4500 - val_loss: 1.0224
# Epoch 2/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5147 - loss: 1.0123 - val_accuracy: 0.7500 - val_loss: 0.9815
# Epoch 3/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7242 - loss: 0.9703 - val_accuracy: 0.7500 - val_loss: 0.9485
# Epoch 4/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7688 - loss: 0.9359 - val_accuracy: 0.7500 - val_loss: 0.9189
# Epoch 5/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7715 - loss: 0.9078 - val_accuracy: 0.7500 - val_loss: 0.8944
# Epoch 6/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7715 - loss: 0.8828 - val_accuracy: 0.7500 - val_loss: 0.8729
# Epoch 7/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7796 - loss: 0.8597 - val_accuracy: 0.7500 - val_loss: 0.8510
# Epoch 8/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7828 - loss: 0.8369 - val_accuracy: 0.8000 - val_loss: 0.8289
# Epoch 9/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7828 - loss: 0.8138 - val_accuracy: 0.8000 - val_loss: 0.8069
# Epoch 10/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7835 - loss: 0.7908 - val_accuracy: 0.8000 - val_loss: 0.7849
# Epoch 11/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7835 - loss: 0.7678 - val_accuracy: 0.8000 - val_loss: 0.7630
# Epoch 12/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7835 - loss: 0.7451 - val_accuracy: 0.8000 - val_loss: 0.7414
# Epoch 13/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7835 - loss: 0.7228 - val_accuracy: 0.8000 - val_loss: 0.7202
# Epoch 14/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7846 - loss: 0.7010 - val_accuracy: 0.8000 - val_loss: 0.6996
# Epoch 15/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7846 - loss: 0.6798 - val_accuracy: 0.8000 - val_loss: 0.6796
# Epoch 16/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7846 - loss: 0.6593 - val_accuracy: 0.8000 - val_loss: 0.6604
# Epoch 17/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7846 - loss: 0.6395 - val_accuracy: 0.8000 - val_loss: 0.6418
# Epoch 18/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7846 - loss: 0.6206 - val_accuracy: 0.8000 - val_loss: 0.6240
# Epoch 19/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7846 - loss: 0.6024 - val_accuracy: 0.8000 - val_loss: 0.6070
# Epoch 20/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7846 - loss: 0.5851 - val_accuracy: 0.8000 - val_loss: 0.5907
# Epoch 21/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7846 - loss: 0.5685 - val_accuracy: 0.8000 - val_loss: 0.5751
# Epoch 22/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7846 - loss: 0.5526 - val_accuracy: 0.8000 - val_loss: 0.5601
# Epoch 23/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7846 - loss: 0.5375 - val_accuracy: 0.8000 - val_loss: 0.5458
# Epoch 24/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7846 - loss: 0.5230 - val_accuracy: 0.8000 - val_loss: 0.5323
# Epoch 25/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7846 - loss: 0.5092 - val_accuracy: 0.8000 - val_loss: 0.5192
# Epoch 26/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7846 - loss: 0.4960 - val_accuracy: 0.8000 - val_loss: 0.5067
# Epoch 27/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7859 - loss: 0.4834 - val_accuracy: 0.8000 - val_loss: 0.4944
# Epoch 28/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7859 - loss: 0.4712 - val_accuracy: 0.8000 - val_loss: 0.4826
# Epoch 29/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7859 - loss: 0.4596 - val_accuracy: 0.8000 - val_loss: 0.4712
# Epoch 30/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7859 - loss: 0.4483 - val_accuracy: 0.8000 - val_loss: 0.4598
# Epoch 31/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7959 - loss: 0.4374 - val_accuracy: 0.8500 - val_loss: 0.4482
# Epoch 32/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7959 - loss: 0.4267 - val_accuracy: 0.8500 - val_loss: 0.4366
# Epoch 33/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8147 - loss: 0.4164 - val_accuracy: 0.8500 - val_loss: 0.4249
# Epoch 34/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8294 - loss: 0.4060 - val_accuracy: 0.9000 - val_loss: 0.4126
# Epoch 35/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8446 - loss: 0.3950 - val_accuracy: 0.9000 - val_loss: 0.3995
# Epoch 36/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8566 - loss: 0.3832 - val_accuracy: 0.9000 - val_loss: 0.3873
# Epoch 37/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9011 - loss: 0.3719 - val_accuracy: 0.9500 - val_loss: 0.3757
# Epoch 38/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9055 - loss: 0.3610 - val_accuracy: 0.9500 - val_loss: 0.3639
# Epoch 39/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9175 - loss: 0.3504 - val_accuracy: 0.9500 - val_loss: 0.3523
# Epoch 40/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9256 - loss: 0.3399 - val_accuracy: 0.9500 - val_loss: 0.3410
# Epoch 41/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9267 - loss: 0.3297 - val_accuracy: 0.9500 - val_loss: 0.3301
# Epoch 42/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9281 - loss: 0.3198 - val_accuracy: 0.9500 - val_loss: 0.3196
# Epoch 43/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9322 - loss: 0.3101 - val_accuracy: 0.9500 - val_loss: 0.3095
# Epoch 44/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9333 - loss: 0.3007 - val_accuracy: 0.9500 - val_loss: 0.2998
# Epoch 45/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9333 - loss: 0.2916 - val_accuracy: 0.9500 - val_loss: 0.2904
# Epoch 46/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9333 - loss: 0.2828 - val_accuracy: 0.9500 - val_loss: 0.2814
# Epoch 47/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9514 - loss: 0.2743 - val_accuracy: 0.9500 - val_loss: 0.2727
# Epoch 48/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9525 - loss: 0.2662 - val_accuracy: 0.9500 - val_loss: 0.2644
# Epoch 49/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9644 - loss: 0.2583 - val_accuracy: 0.9500 - val_loss: 0.2566
# Epoch 50/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9644 - loss: 0.2508 - val_accuracy: 0.9500 - val_loss: 0.2490
# Epoch 51/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9651 - loss: 0.2435 - val_accuracy: 0.9500 - val_loss: 0.2417
# Epoch 52/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9640 - loss: 0.2366 - val_accuracy: 0.9500 - val_loss: 0.2347
# Epoch 53/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9640 - loss: 0.2299 - val_accuracy: 0.9500 - val_loss: 0.2280
# Epoch 54/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9640 - loss: 0.2235 - val_accuracy: 0.9500 - val_loss: 0.2215
# Epoch 55/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9640 - loss: 0.2174 - val_accuracy: 0.9500 - val_loss: 0.2153
# Epoch 56/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9640 - loss: 0.2115 - val_accuracy: 0.9500 - val_loss: 0.2094
# Epoch 57/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9640 - loss: 0.2058 - val_accuracy: 0.9500 - val_loss: 0.2036
# Epoch 58/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9640 - loss: 0.2004 - val_accuracy: 0.9500 - val_loss: 0.1981
# Epoch 59/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9682 - loss: 0.1951 - val_accuracy: 0.9500 - val_loss: 0.1928
# Epoch 60/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9682 - loss: 0.1901 - val_accuracy: 0.9500 - val_loss: 0.1877
# Epoch 61/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9682 - loss: 0.1852 - val_accuracy: 0.9500 - val_loss: 0.1827
# Epoch 62/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9682 - loss: 0.1806 - val_accuracy: 0.9500 - val_loss: 0.1780
# Epoch 63/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9689 - loss: 0.1761 - val_accuracy: 0.9500 - val_loss: 0.1734
# Epoch 64/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9689 - loss: 0.1718 - val_accuracy: 0.9500 - val_loss: 0.1690
# Epoch 65/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9689 - loss: 0.1677 - val_accuracy: 0.9500 - val_loss: 0.1648
# Epoch 66/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9700 - loss: 0.1637 - val_accuracy: 0.9500 - val_loss: 0.1607
# Epoch 67/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9700 - loss: 0.1599 - val_accuracy: 0.9500 - val_loss: 0.1568
# Epoch 68/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9781 - loss: 0.1562 - val_accuracy: 0.9500 - val_loss: 0.1530
# Epoch 69/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9781 - loss: 0.1526 - val_accuracy: 0.9500 - val_loss: 0.1493
# Epoch 70/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9781 - loss: 0.1492 - val_accuracy: 0.9500 - val_loss: 0.1458
# Epoch 71/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9799 - loss: 0.1459 - val_accuracy: 1.0000 - val_loss: 0.1424
# Epoch 72/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9799 - loss: 0.1428 - val_accuracy: 1.0000 - val_loss: 0.1390
# Epoch 73/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9799 - loss: 0.1397 - val_accuracy: 1.0000 - val_loss: 0.1358
# Epoch 74/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9799 - loss: 0.1368 - val_accuracy: 1.0000 - val_loss: 0.1328
# Epoch 75/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9799 - loss: 0.1339 - val_accuracy: 1.0000 - val_loss: 0.1298
# Epoch 76/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9799 - loss: 0.1312 - val_accuracy: 1.0000 - val_loss: 0.1269
# Epoch 77/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9799 - loss: 0.1285 - val_accuracy: 1.0000 - val_loss: 0.1241
# Epoch 78/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9799 - loss: 0.1260 - val_accuracy: 1.0000 - val_loss: 0.1214
# Epoch 79/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9773 - loss: 0.1235 - val_accuracy: 1.0000 - val_loss: 0.1188
# Epoch 80/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9773 - loss: 0.1212 - val_accuracy: 1.0000 - val_loss: 0.1162
# Epoch 81/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9773 - loss: 0.1189 - val_accuracy: 1.0000 - val_loss: 0.1137
# Epoch 82/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9773 - loss: 0.1166 - val_accuracy: 1.0000 - val_loss: 0.1113
# Epoch 83/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9773 - loss: 0.1145 - val_accuracy: 1.0000 - val_loss: 0.1090
# Epoch 84/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9773 - loss: 0.1124 - val_accuracy: 1.0000 - val_loss: 0.1068
# Epoch 85/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9773 - loss: 0.1104 - val_accuracy: 1.0000 - val_loss: 0.1046
# Epoch 86/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9773 - loss: 0.1085 - val_accuracy: 1.0000 - val_loss: 0.1024
# Epoch 87/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9773 - loss: 0.1066 - val_accuracy: 1.0000 - val_loss: 0.1004
# Epoch 88/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9773 - loss: 0.1048 - val_accuracy: 1.0000 - val_loss: 0.0984
# Epoch 89/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9773 - loss: 0.1030 - val_accuracy: 1.0000 - val_loss: 0.0964
# Epoch 90/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9773 - loss: 0.1013 - val_accuracy: 1.0000 - val_loss: 0.0945
# Epoch 91/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9773 - loss: 0.0996 - val_accuracy: 1.0000 - val_loss: 0.0927
# Epoch 92/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9773 - loss: 0.0980 - val_accuracy: 1.0000 - val_loss: 0.0909
# Epoch 93/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9773 - loss: 0.0965 - val_accuracy: 1.0000 - val_loss: 0.0892
# Epoch 94/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9773 - loss: 0.0950 - val_accuracy: 1.0000 - val_loss: 0.0875
# Epoch 95/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9773 - loss: 0.0935 - val_accuracy: 1.0000 - val_loss: 0.0859
# Epoch 96/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9773 - loss: 0.0921 - val_accuracy: 1.0000 - val_loss: 0.0843
# Epoch 97/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9773 - loss: 0.0907 - val_accuracy: 1.0000 - val_loss: 0.0827
# Epoch 98/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9773 - loss: 0.0894 - val_accuracy: 1.0000 - val_loss: 0.0812
# Epoch 99/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9773 - loss: 0.0881 - val_accuracy: 1.0000 - val_loss: 0.0797
# Epoch 100/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9773 - loss: 0.0868 - val_accuracy: 1.0000 - val_loss: 0.0783
# Epoch 101/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9773 - loss: 0.0856 - val_accuracy: 1.0000 - val_loss: 0.0769
# Epoch 102/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9773 - loss: 0.0844 - val_accuracy: 1.0000 - val_loss: 0.0755
# Epoch 103/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9773 - loss: 0.0832 - val_accuracy: 1.0000 - val_loss: 0.0742
# Epoch 104/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9773 - loss: 0.0821 - val_accuracy: 1.0000 - val_loss: 0.0729
# Epoch 105/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9773 - loss: 0.0810 - val_accuracy: 1.0000 - val_loss: 0.0716
# Epoch 106/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9773 - loss: 0.0799 - val_accuracy: 1.0000 - val_loss: 0.0704
# Epoch 107/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9773 - loss: 0.0789 - val_accuracy: 1.0000 - val_loss: 0.0692
# Epoch 108/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9773 - loss: 0.0778 - val_accuracy: 1.0000 - val_loss: 0.0680
# Epoch 109/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9773 - loss: 0.0769 - val_accuracy: 1.0000 - val_loss: 0.0669
# Epoch 110/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9773 - loss: 0.0759 - val_accuracy: 1.0000 - val_loss: 0.0658
# Epoch 111/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9773 - loss: 0.0750 - val_accuracy: 1.0000 - val_loss: 0.0647
# Epoch 112/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9773 - loss: 0.0740 - val_accuracy: 1.0000 - val_loss: 0.0636
# Epoch 113/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9773 - loss: 0.0731 - val_accuracy: 1.0000 - val_loss: 0.0626
# Epoch 114/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9784 - loss: 0.0723 - val_accuracy: 1.0000 - val_loss: 0.0616
# Epoch 115/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9784 - loss: 0.0714 - val_accuracy: 1.0000 - val_loss: 0.0606
# Epoch 116/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9784 - loss: 0.0706 - val_accuracy: 1.0000 - val_loss: 0.0596
# Epoch 117/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9784 - loss: 0.0698 - val_accuracy: 1.0000 - val_loss: 0.0587
# Epoch 118/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9784 - loss: 0.0690 - val_accuracy: 1.0000 - val_loss: 0.0578
# Epoch 119/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9784 - loss: 0.0682 - val_accuracy: 1.0000 - val_loss: 0.0569
# Epoch 120/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9784 - loss: 0.0675 - val_accuracy: 1.0000 - val_loss: 0.0560
# Epoch 121/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9784 - loss: 0.0667 - val_accuracy: 1.0000 - val_loss: 0.0552
# Epoch 122/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9784 - loss: 0.0660 - val_accuracy: 1.0000 - val_loss: 0.0543
# Epoch 123/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9784 - loss: 0.0653 - val_accuracy: 1.0000 - val_loss: 0.0535
# Epoch 124/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9784 - loss: 0.0646 - val_accuracy: 1.0000 - val_loss: 0.0527
# Epoch 125/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9784 - loss: 0.0640 - val_accuracy: 1.0000 - val_loss: 0.0519
# Epoch 126/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9784 - loss: 0.0633 - val_accuracy: 1.0000 - val_loss: 0.0511
# Epoch 127/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9784 - loss: 0.0627 - val_accuracy: 1.0000 - val_loss: 0.0504
# Epoch 128/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9784 - loss: 0.0621 - val_accuracy: 1.0000 - val_loss: 0.0497
# Epoch 129/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9784 - loss: 0.0614 - val_accuracy: 1.0000 - val_loss: 0.0490
# Epoch 130/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9784 - loss: 0.0608 - val_accuracy: 1.0000 - val_loss: 0.0482
# Epoch 131/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9784 - loss: 0.0603 - val_accuracy: 1.0000 - val_loss: 0.0476
# Epoch 132/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9784 - loss: 0.0597 - val_accuracy: 1.0000 - val_loss: 0.0469
# Epoch 133/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9784 - loss: 0.0591 - val_accuracy: 1.0000 - val_loss: 0.0462
# Epoch 134/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9832 - loss: 0.0586 - val_accuracy: 1.0000 - val_loss: 0.0456
# Epoch 135/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9832 - loss: 0.0580 - val_accuracy: 1.0000 - val_loss: 0.0449
# Epoch 136/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9832 - loss: 0.0575 - val_accuracy: 1.0000 - val_loss: 0.0443
# Epoch 137/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9832 - loss: 0.0570 - val_accuracy: 1.0000 - val_loss: 0.0437
# Epoch 138/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9832 - loss: 0.0565 - val_accuracy: 1.0000 - val_loss: 0.0431
# Epoch 139/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9832 - loss: 0.0560 - val_accuracy: 1.0000 - val_loss: 0.0425
# Epoch 140/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9832 - loss: 0.0555 - val_accuracy: 1.0000 - val_loss: 0.0420
# Epoch 141/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9832 - loss: 0.0550 - val_accuracy: 1.0000 - val_loss: 0.0414
# Epoch 142/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9832 - loss: 0.0546 - val_accuracy: 1.0000 - val_loss: 0.0409
# Epoch 143/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9832 - loss: 0.0541 - val_accuracy: 1.0000 - val_loss: 0.0403
# Epoch 144/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9832 - loss: 0.0537 - val_accuracy: 1.0000 - val_loss: 0.0398
# Epoch 145/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9832 - loss: 0.0532 - val_accuracy: 1.0000 - val_loss: 0.0393
# Epoch 146/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9832 - loss: 0.0528 - val_accuracy: 1.0000 - val_loss: 0.0388
# Epoch 147/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9832 - loss: 0.0524 - val_accuracy: 1.0000 - val_loss: 0.0383
# Epoch 148/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9832 - loss: 0.0520 - val_accuracy: 1.0000 - val_loss: 0.0378
# Epoch 149/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9832 - loss: 0.0515 - val_accuracy: 1.0000 - val_loss: 0.0373
# Epoch 150/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9832 - loss: 0.0511 - val_accuracy: 1.0000 - val_loss: 0.0368
# Epoch 151/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9832 - loss: 0.0508 - val_accuracy: 1.0000 - val_loss: 0.0364
# Epoch 152/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9832 - loss: 0.0504 - val_accuracy: 1.0000 - val_loss: 0.0359
# Epoch 153/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9832 - loss: 0.0500 - val_accuracy: 1.0000 - val_loss: 0.0355
# Epoch 154/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9832 - loss: 0.0496 - val_accuracy: 1.0000 - val_loss: 0.0351
# Epoch 155/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9832 - loss: 0.0493 - val_accuracy: 1.0000 - val_loss: 0.0346
# Epoch 156/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9832 - loss: 0.0489 - val_accuracy: 1.0000 - val_loss: 0.0342
# Epoch 157/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9832 - loss: 0.0485 - val_accuracy: 1.0000 - val_loss: 0.0338
# Epoch 158/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9832 - loss: 0.0482 - val_accuracy: 1.0000 - val_loss: 0.0334
# Epoch 159/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9832 - loss: 0.0479 - val_accuracy: 1.0000 - val_loss: 0.0330
# Epoch 160/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9832 - loss: 0.0475 - val_accuracy: 1.0000 - val_loss: 0.0326
# Epoch 161/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9832 - loss: 0.0472 - val_accuracy: 1.0000 - val_loss: 0.0322
# Epoch 162/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9832 - loss: 0.0469 - val_accuracy: 1.0000 - val_loss: 0.0319
# Epoch 163/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9832 - loss: 0.0466 - val_accuracy: 1.0000 - val_loss: 0.0315
# Epoch 164/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9832 - loss: 0.0462 - val_accuracy: 1.0000 - val_loss: 0.0311
# Epoch 165/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9832 - loss: 0.0459 - val_accuracy: 1.0000 - val_loss: 0.0308
# Epoch 166/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9832 - loss: 0.0456 - val_accuracy: 1.0000 - val_loss: 0.0304
# Epoch 167/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9832 - loss: 0.0453 - val_accuracy: 1.0000 - val_loss: 0.0301
# Epoch 168/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9832 - loss: 0.0451 - val_accuracy: 1.0000 - val_loss: 0.0297
# Epoch 169/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9832 - loss: 0.0448 - val_accuracy: 1.0000 - val_loss: 0.0294
# Epoch 170/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9832 - loss: 0.0445 - val_accuracy: 1.0000 - val_loss: 0.0291
# Epoch 171/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9832 - loss: 0.0442 - val_accuracy: 1.0000 - val_loss: 0.0288
# Epoch 172/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9832 - loss: 0.0439 - val_accuracy: 1.0000 - val_loss: 0.0284
# Epoch 173/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9832 - loss: 0.0437 - val_accuracy: 1.0000 - val_loss: 0.0281
# Epoch 174/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9832 - loss: 0.0434 - val_accuracy: 1.0000 - val_loss: 0.0278
# Epoch 175/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0431 - val_accuracy: 1.0000 - val_loss: 0.0275
# Epoch 176/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9879 - loss: 0.0429 - val_accuracy: 1.0000 - val_loss: 0.0272
# Epoch 177/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9879 - loss: 0.0426 - val_accuracy: 1.0000 - val_loss: 0.0269
# Epoch 178/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9879 - loss: 0.0424 - val_accuracy: 1.0000 - val_loss: 0.0267
# Epoch 179/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9879 - loss: 0.0421 - val_accuracy: 1.0000 - val_loss: 0.0264
# Epoch 180/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9879 - loss: 0.0419 - val_accuracy: 1.0000 - val_loss: 0.0261
# Epoch 181/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9879 - loss: 0.0417 - val_accuracy: 1.0000 - val_loss: 0.0258
# Epoch 182/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9879 - loss: 0.0414 - val_accuracy: 1.0000 - val_loss: 0.0256
# Epoch 183/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9879 - loss: 0.0412 - val_accuracy: 1.0000 - val_loss: 0.0253
# Epoch 184/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9879 - loss: 0.0410 - val_accuracy: 1.0000 - val_loss: 0.0250
# Epoch 185/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9879 - loss: 0.0407 - val_accuracy: 1.0000 - val_loss: 0.0248
# Epoch 186/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9879 - loss: 0.0405 - val_accuracy: 1.0000 - val_loss: 0.0245
# Epoch 187/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9879 - loss: 0.0403 - val_accuracy: 1.0000 - val_loss: 0.0243
# Epoch 188/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9879 - loss: 0.0401 - val_accuracy: 1.0000 - val_loss: 0.0241
# Epoch 189/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9879 - loss: 0.0399 - val_accuracy: 1.0000 - val_loss: 0.0238
# Epoch 190/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9879 - loss: 0.0397 - val_accuracy: 1.0000 - val_loss: 0.0236
# Epoch 191/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9879 - loss: 0.0395 - val_accuracy: 1.0000 - val_loss: 0.0234
# Epoch 192/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9879 - loss: 0.0393 - val_accuracy: 1.0000 - val_loss: 0.0231
# Epoch 193/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9879 - loss: 0.0391 - val_accuracy: 1.0000 - val_loss: 0.0229
# Epoch 194/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9879 - loss: 0.0389 - val_accuracy: 1.0000 - val_loss: 0.0227
# Epoch 195/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0387 - val_accuracy: 1.0000 - val_loss: 0.0225
# Epoch 196/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0385 - val_accuracy: 1.0000 - val_loss: 0.0222
# Epoch 197/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0383 - val_accuracy: 1.0000 - val_loss: 0.0220
# Epoch 198/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9879 - loss: 0.0381 - val_accuracy: 1.0000 - val_loss: 0.0218
# Epoch 199/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0379 - val_accuracy: 1.0000 - val_loss: 0.0216
# Epoch 200/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0377 - val_accuracy: 1.0000 - val_loss: 0.0214
# Epoch 201/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0375 - val_accuracy: 1.0000 - val_loss: 0.0212
# Epoch 202/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0374 - val_accuracy: 1.0000 - val_loss: 0.0210
# Epoch 203/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0372 - val_accuracy: 1.0000 - val_loss: 0.0208
# Epoch 204/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0370 - val_accuracy: 1.0000 - val_loss: 0.0206
# Epoch 205/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0368 - val_accuracy: 1.0000 - val_loss: 0.0204
# Epoch 206/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0367 - val_accuracy: 1.0000 - val_loss: 0.0203
# Epoch 207/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0365 - val_accuracy: 1.0000 - val_loss: 0.0201
# Epoch 208/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0363 - val_accuracy: 1.0000 - val_loss: 0.0199
# Epoch 209/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0362 - val_accuracy: 1.0000 - val_loss: 0.0197
# Epoch 210/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0360 - val_accuracy: 1.0000 - val_loss: 0.0195
# Epoch 211/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0359 - val_accuracy: 1.0000 - val_loss: 0.0194
# Epoch 212/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0357 - val_accuracy: 1.0000 - val_loss: 0.0192
# Epoch 213/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0355 - val_accuracy: 1.0000 - val_loss: 0.0190
# Epoch 214/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0354 - val_accuracy: 1.0000 - val_loss: 0.0189
# Epoch 215/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0352 - val_accuracy: 1.0000 - val_loss: 0.0187
# Epoch 216/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9879 - loss: 0.0351 - val_accuracy: 1.0000 - val_loss: 0.0185
# Epoch 217/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0349 - val_accuracy: 1.0000 - val_loss: 0.0184
# Epoch 218/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0348 - val_accuracy: 1.0000 - val_loss: 0.0182
# Epoch 219/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0346 - val_accuracy: 1.0000 - val_loss: 0.0181
# Epoch 220/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0345 - val_accuracy: 1.0000 - val_loss: 0.0179
# Epoch 221/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9879 - loss: 0.0344 - val_accuracy: 1.0000 - val_loss: 0.0178
# Epoch 222/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0342 - val_accuracy: 1.0000 - val_loss: 0.0176
# Epoch 223/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0341 - val_accuracy: 1.0000 - val_loss: 0.0175
# Epoch 224/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0339 - val_accuracy: 1.0000 - val_loss: 0.0173
# Epoch 225/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9879 - loss: 0.0338 - val_accuracy: 1.0000 - val_loss: 0.0172
# Epoch 226/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0337 - val_accuracy: 1.0000 - val_loss: 0.0170
# Epoch 227/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0335 - val_accuracy: 1.0000 - val_loss: 0.0169
# Epoch 228/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0334 - val_accuracy: 1.0000 - val_loss: 0.0167
# Epoch 229/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0333 - val_accuracy: 1.0000 - val_loss: 0.0166
# Epoch 230/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0331 - val_accuracy: 1.0000 - val_loss: 0.0164
# Epoch 231/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0330 - val_accuracy: 1.0000 - val_loss: 0.0163
# Epoch 232/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0329 - val_accuracy: 1.0000 - val_loss: 0.0162
# Epoch 233/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0328 - val_accuracy: 1.0000 - val_loss: 0.0161
# Epoch 234/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0326 - val_accuracy: 1.0000 - val_loss: 0.0159
# Epoch 235/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0325 - val_accuracy: 1.0000 - val_loss: 0.0158
# Epoch 236/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0324 - val_accuracy: 1.0000 - val_loss: 0.0157
# Epoch 237/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0323 - val_accuracy: 1.0000 - val_loss: 0.0155
# Epoch 238/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9879 - loss: 0.0322 - val_accuracy: 1.0000 - val_loss: 0.0154
# Epoch 239/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0321 - val_accuracy: 1.0000 - val_loss: 0.0153
# Epoch 240/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9879 - loss: 0.0319 - val_accuracy: 1.0000 - val_loss: 0.0152
# Epoch 241/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0318 - val_accuracy: 1.0000 - val_loss: 0.0151
# Epoch 242/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0317 - val_accuracy: 1.0000 - val_loss: 0.0149
# Epoch 243/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9879 - loss: 0.0316 - val_accuracy: 1.0000 - val_loss: 0.0148
# Epoch 244/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0315 - val_accuracy: 1.0000 - val_loss: 0.0147
# Epoch 245/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9879 - loss: 0.0314 - val_accuracy: 1.0000 - val_loss: 0.0146
# Epoch 246/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0313 - val_accuracy: 1.0000 - val_loss: 0.0145
# Epoch 247/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9879 - loss: 0.0312 - val_accuracy: 1.0000 - val_loss: 0.0144
# Epoch 248/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0310 - val_accuracy: 1.0000 - val_loss: 0.0143
# Epoch 249/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0309 - val_accuracy: 1.0000 - val_loss: 0.0142
# Epoch 250/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9879 - loss: 0.0308 - val_accuracy: 1.0000 - val_loss: 0.0141
# Epoch 251/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9879 - loss: 0.0307 - val_accuracy: 1.0000 - val_loss: 0.0140
# Epoch 252/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9879 - loss: 0.0306 - val_accuracy: 1.0000 - val_loss: 0.0139
# Epoch 253/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9879 - loss: 0.0305 - val_accuracy: 1.0000 - val_loss: 0.0138
# Epoch 254/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0304 - val_accuracy: 1.0000 - val_loss: 0.0137
# Epoch 255/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0303 - val_accuracy: 1.0000 - val_loss: 0.0136
# Epoch 256/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9879 - loss: 0.0302 - val_accuracy: 1.0000 - val_loss: 0.0135
# Epoch 257/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9879 - loss: 0.0301 - val_accuracy: 1.0000 - val_loss: 0.0134
# Epoch 258/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9879 - loss: 0.0300 - val_accuracy: 1.0000 - val_loss: 0.0133
# Epoch 259/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9879 - loss: 0.0299 - val_accuracy: 1.0000 - val_loss: 0.0132
# Epoch 260/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9879 - loss: 0.0298 - val_accuracy: 1.0000 - val_loss: 0.0131
# Epoch 261/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0297 - val_accuracy: 1.0000 - val_loss: 0.0130
# Epoch 262/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0297 - val_accuracy: 1.0000 - val_loss: 0.0129
# Epoch 263/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0296 - val_accuracy: 1.0000 - val_loss: 0.0128
# Epoch 264/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0295 - val_accuracy: 1.0000 - val_loss: 0.0127
# Epoch 265/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0294 - val_accuracy: 1.0000 - val_loss: 0.0126
# Epoch 266/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0293 - val_accuracy: 1.0000 - val_loss: 0.0125
# Epoch 267/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0292 - val_accuracy: 1.0000 - val_loss: 0.0124
# Epoch 268/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0291 - val_accuracy: 1.0000 - val_loss: 0.0123
# Epoch 269/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9879 - loss: 0.0290 - val_accuracy: 1.0000 - val_loss: 0.0122
# Epoch 270/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9879 - loss: 0.0289 - val_accuracy: 1.0000 - val_loss: 0.0122
# Epoch 271/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9879 - loss: 0.0288 - val_accuracy: 1.0000 - val_loss: 0.0121
# Epoch 272/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9879 - loss: 0.0288 - val_accuracy: 1.0000 - val_loss: 0.0120
# Epoch 273/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9879 - loss: 0.0287 - val_accuracy: 1.0000 - val_loss: 0.0119
# Epoch 274/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0286 - val_accuracy: 1.0000 - val_loss: 0.0118
# Epoch 275/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0285 - val_accuracy: 1.0000 - val_loss: 0.0117
# Epoch 276/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9879 - loss: 0.0284 - val_accuracy: 1.0000 - val_loss: 0.0117
# Epoch 277/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9879 - loss: 0.0283 - val_accuracy: 1.0000 - val_loss: 0.0116
# Epoch 278/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9879 - loss: 0.0282 - val_accuracy: 1.0000 - val_loss: 0.0115
# Epoch 279/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0282 - val_accuracy: 1.0000 - val_loss: 0.0114
# Epoch 280/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0281 - val_accuracy: 1.0000 - val_loss: 0.0113
# Epoch 281/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0280 - val_accuracy: 1.0000 - val_loss: 0.0113
# Epoch 282/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0279 - val_accuracy: 1.0000 - val_loss: 0.0112
# Epoch 283/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0278 - val_accuracy: 1.0000 - val_loss: 0.0111
# Epoch 284/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0278 - val_accuracy: 1.0000 - val_loss: 0.0110
# Epoch 285/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0277 - val_accuracy: 1.0000 - val_loss: 0.0109
# Epoch 286/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0276 - val_accuracy: 1.0000 - val_loss: 0.0109
# Epoch 287/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0275 - val_accuracy: 1.0000 - val_loss: 0.0108
# Epoch 288/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0275 - val_accuracy: 1.0000 - val_loss: 0.0107
# Epoch 289/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0274 - val_accuracy: 1.0000 - val_loss: 0.0107
# Epoch 290/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0273 - val_accuracy: 1.0000 - val_loss: 0.0106
# Epoch 291/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0272 - val_accuracy: 1.0000 - val_loss: 0.0105
# Epoch 292/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0272 - val_accuracy: 1.0000 - val_loss: 0.0105
# Epoch 293/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0271 - val_accuracy: 1.0000 - val_loss: 0.0104
# Epoch 294/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0270 - val_accuracy: 1.0000 - val_loss: 0.0103
# Epoch 295/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0270 - val_accuracy: 1.0000 - val_loss: 0.0103
# Epoch 296/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0269 - val_accuracy: 1.0000 - val_loss: 0.0102
# Epoch 297/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0268 - val_accuracy: 1.0000 - val_loss: 0.0101
# Epoch 298/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0267 - val_accuracy: 1.0000 - val_loss: 0.0101
# Epoch 299/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0267 - val_accuracy: 1.0000 - val_loss: 0.0100
# Epoch 300/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0266 - val_accuracy: 1.0000 - val_loss: 0.0100
# Epoch 301/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0265 - val_accuracy: 1.0000 - val_loss: 0.0099
# Epoch 302/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0265 - val_accuracy: 1.0000 - val_loss: 0.0098
# Epoch 303/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0264 - val_accuracy: 1.0000 - val_loss: 0.0098
# Epoch 304/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0263 - val_accuracy: 1.0000 - val_loss: 0.0097
# Epoch 305/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0263 - val_accuracy: 1.0000 - val_loss: 0.0097
# Epoch 306/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9879 - loss: 0.0262 - val_accuracy: 1.0000 - val_loss: 0.0096
# Epoch 307/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0261 - val_accuracy: 1.0000 - val_loss: 0.0095
# Epoch 308/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0261 - val_accuracy: 1.0000 - val_loss: 0.0095
# Epoch 309/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0260 - val_accuracy: 1.0000 - val_loss: 0.0094
# Epoch 310/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0260 - val_accuracy: 1.0000 - val_loss: 0.0094
# Epoch 311/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0259 - val_accuracy: 1.0000 - val_loss: 0.0093
# Epoch 312/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0258 - val_accuracy: 1.0000 - val_loss: 0.0093
# Epoch 313/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9879 - loss: 0.0258 - val_accuracy: 1.0000 - val_loss: 0.0092
# Epoch 314/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0257 - val_accuracy: 1.0000 - val_loss: 0.0092
# Epoch 315/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9879 - loss: 0.0256 - val_accuracy: 1.0000 - val_loss: 0.0091
# Epoch 316/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0256 - val_accuracy: 1.0000 - val_loss: 0.0090
# Epoch 317/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0255 - val_accuracy: 1.0000 - val_loss: 0.0090
# Epoch 318/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9879 - loss: 0.0255 - val_accuracy: 1.0000 - val_loss: 0.0089
# Epoch 319/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9879 - loss: 0.0254 - val_accuracy: 1.0000 - val_loss: 0.0089
# Epoch 320/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9879 - loss: 0.0253 - val_accuracy: 1.0000 - val_loss: 0.0088
# Epoch 321/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9879 - loss: 0.0253 - val_accuracy: 1.0000 - val_loss: 0.0088
# Epoch 322/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9879 - loss: 0.0252 - val_accuracy: 1.0000 - val_loss: 0.0087
# Epoch 323/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9879 - loss: 0.0252 - val_accuracy: 1.0000 - val_loss: 0.0087
# Epoch 324/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0251 - val_accuracy: 1.0000 - val_loss: 0.0086
# Epoch 325/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9879 - loss: 0.0251 - val_accuracy: 1.0000 - val_loss: 0.0086
# Epoch 326/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9879 - loss: 0.0250 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 327/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0249 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 328/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9879 - loss: 0.0249 - val_accuracy: 1.0000 - val_loss: 0.0085
# Epoch 329/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0248 - val_accuracy: 1.0000 - val_loss: 0.0084
# Epoch 330/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0248 - val_accuracy: 1.0000 - val_loss: 0.0084
# Epoch 331/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9879 - loss: 0.0247 - val_accuracy: 1.0000 - val_loss: 0.0083
# Epoch 332/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9879 - loss: 0.0247 - val_accuracy: 1.0000 - val_loss: 0.0083
# Epoch 333/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0246 - val_accuracy: 1.0000 - val_loss: 0.0082
# Epoch 334/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0245 - val_accuracy: 1.0000 - val_loss: 0.0082
# Epoch 335/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9879 - loss: 0.0245 - val_accuracy: 1.0000 - val_loss: 0.0081
# Epoch 336/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0244 - val_accuracy: 1.0000 - val_loss: 0.0081
# Epoch 337/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0244 - val_accuracy: 1.0000 - val_loss: 0.0080
# Epoch 338/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0243 - val_accuracy: 1.0000 - val_loss: 0.0080
# Epoch 339/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0243 - val_accuracy: 1.0000 - val_loss: 0.0080
# Epoch 340/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0242 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 341/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0242 - val_accuracy: 1.0000 - val_loss: 0.0079
# Epoch 342/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9879 - loss: 0.0241 - val_accuracy: 1.0000 - val_loss: 0.0078
# Epoch 343/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9879 - loss: 0.0241 - val_accuracy: 1.0000 - val_loss: 0.0078
# Epoch 344/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9898 - loss: 0.0240 - val_accuracy: 1.0000 - val_loss: 0.0077
# Epoch 345/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9898 - loss: 0.0240 - val_accuracy: 1.0000 - val_loss: 0.0077
# Epoch 346/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9898 - loss: 0.0239 - val_accuracy: 1.0000 - val_loss: 0.0077
# Epoch 347/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0239 - val_accuracy: 1.0000 - val_loss: 0.0076
# Epoch 348/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0238 - val_accuracy: 1.0000 - val_loss: 0.0076
# Epoch 349/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0238 - val_accuracy: 1.0000 - val_loss: 0.0075
# Epoch 350/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0237 - val_accuracy: 1.0000 - val_loss: 0.0075
# Epoch 351/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0237 - val_accuracy: 1.0000 - val_loss: 0.0075
# Epoch 352/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9898 - loss: 0.0236 - val_accuracy: 1.0000 - val_loss: 0.0074
# Epoch 353/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0236 - val_accuracy: 1.0000 - val_loss: 0.0074
# Epoch 354/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9898 - loss: 0.0235 - val_accuracy: 1.0000 - val_loss: 0.0073
# Epoch 355/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0235 - val_accuracy: 1.0000 - val_loss: 0.0073
# Epoch 356/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9898 - loss: 0.0234 - val_accuracy: 1.0000 - val_loss: 0.0073
# Epoch 357/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9898 - loss: 0.0234 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 358/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0233 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 359/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0233 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 360/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9898 - loss: 0.0233 - val_accuracy: 1.0000 - val_loss: 0.0071
# Epoch 361/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9898 - loss: 0.0232 - val_accuracy: 1.0000 - val_loss: 0.0071
# Epoch 362/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0232 - val_accuracy: 1.0000 - val_loss: 0.0071
# Epoch 363/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0231 - val_accuracy: 1.0000 - val_loss: 0.0070
# Epoch 364/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9898 - loss: 0.0231 - val_accuracy: 1.0000 - val_loss: 0.0070
# Epoch 365/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9898 - loss: 0.0230 - val_accuracy: 1.0000 - val_loss: 0.0070
# Epoch 366/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0230 - val_accuracy: 1.0000 - val_loss: 0.0069
# Epoch 367/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9898 - loss: 0.0229 - val_accuracy: 1.0000 - val_loss: 0.0069
# Epoch 368/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9898 - loss: 0.0229 - val_accuracy: 1.0000 - val_loss: 0.0068
# Epoch 369/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9898 - loss: 0.0228 - val_accuracy: 1.0000 - val_loss: 0.0068
# Epoch 370/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9898 - loss: 0.0228 - val_accuracy: 1.0000 - val_loss: 0.0068
# Epoch 371/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9898 - loss: 0.0228 - val_accuracy: 1.0000 - val_loss: 0.0068
# Epoch 372/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9898 - loss: 0.0227 - val_accuracy: 1.0000 - val_loss: 0.0067
# Epoch 373/500
# ...
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9898 - loss: 0.0225 - val_accuracy: 1.0000 - val_loss: 0.0066
# Epoch 378/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9898 - loss: 0.0225 - val_accuracy: 1.0000 - val_loss: 0.0065
# Epoch 379/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9898 - loss: 0.0224 - val_accuracy: 1.0000 - val_loss: 0.0065
# Epoch 380/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9898 - loss: 0.0224 - val_accuracy: 1.0000 - val_loss: 0.0065
# Epoch 381/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9898 - loss: 0.0223 - val_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 382/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9898 - loss: 0.0223 - val_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 383/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9898 - loss: 0.0223 - val_accuracy: 1.0000 - val_loss: 0.0064
# Epoch 384/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9898 - loss: 0.0222 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 385/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9898 - loss: 0.0222 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 386/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9898 - loss: 0.0221 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 387/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9898 - loss: 0.0221 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 388/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9898 - loss: 0.0221 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 389/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9898 - loss: 0.0220 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 390/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9898 - loss: 0.0220 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 391/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9898 - loss: 0.0219 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 392/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9898 - loss: 0.0219 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 393/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9898 - loss: 0.0219 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 394/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9898 - loss: 0.0218 - val_accuracy: 1.0000 - val_loss: 0.0061
# Epoch 395/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9898 - loss: 0.0218 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 396/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9898 - loss: 0.0218 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 397/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9898 - loss: 0.0217 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 398/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0217 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 399/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0216 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 400/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9898 - loss: 0.0216 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 401/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0216 - val_accuracy: 1.0000 - val_loss: 0.0059
# Epoch 402/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0215 - val_accuracy: 1.0000 - val_loss: 0.0058
# Epoch 403/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9898 - loss: 0.0215 - val_accuracy: 1.0000 - val_loss: 0.0058
# Epoch 404/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9898 - loss: 0.0215 - val_accuracy: 1.0000 - val_loss: 0.0058
# Epoch 405/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9898 - loss: 0.0214 - val_accuracy: 1.0000 - val_loss: 0.0058
# Epoch 406/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9898 - loss: 0.0214 - val_accuracy: 1.0000 - val_loss: 0.0057
# Epoch 407/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9898 - loss: 0.0214 - val_accuracy: 1.0000 - val_loss: 0.0057
# Epoch 408/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9898 - loss: 0.0213 - val_accuracy: 1.0000 - val_loss: 0.0057
# Epoch 409/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0213 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 410/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9898 - loss: 0.0212 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 411/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9898 - loss: 0.0212 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 412/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9898 - loss: 0.0212 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 413/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0211 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 414/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0211 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 415/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0211 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 416/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0210 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 417/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9898 - loss: 0.0210 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 418/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9898 - loss: 0.0210 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 419/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9898 - loss: 0.0209 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 420/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9898 - loss: 0.0209 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 421/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9898 - loss: 0.0209 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 422/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9898 - loss: 0.0208 - val_accuracy: 1.0000 - val_loss: 0.0053
# Epoch 423/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9898 - loss: 0.0208 - val_accuracy: 1.0000 - val_loss: 0.0053
# Epoch 424/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9898 - loss: 0.0208 - val_accuracy: 1.0000 - val_loss: 0.0053
# Epoch 425/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9898 - loss: 0.0207 - val_accuracy: 1.0000 - val_loss: 0.0053
# Epoch 426/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0207 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 427/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9898 - loss: 0.0207 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 428/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9898 - loss: 0.0206 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 429/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9898 - loss: 0.0206 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 430/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9898 - loss: 0.0206 - val_accuracy: 1.0000 - val_loss: 0.0052
# Epoch 431/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9898 - loss: 0.0205 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 432/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0205 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 433/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9898 - loss: 0.0205 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 434/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0204 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 435/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9898 - loss: 0.0204 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 436/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0204 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 437/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9898 - loss: 0.0204 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 438/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9898 - loss: 0.0203 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 439/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9919 - loss: 0.0203 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 440/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9919 - loss: 0.0203 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 441/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9919 - loss: 0.0202 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 442/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9919 - loss: 0.0202 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 443/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9919 - loss: 0.0202 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 444/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9919 - loss: 0.0201 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 445/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9919 - loss: 0.0201 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 446/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9919 - loss: 0.0201 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 447/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9919 - loss: 0.0200 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 448/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9919 - loss: 0.0200 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 449/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9919 - loss: 0.0200 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 450/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9919 - loss: 0.0200 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 451/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9919 - loss: 0.0199 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 452/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9919 - loss: 0.0199 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 453/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9919 - loss: 0.0199 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 454/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9919 - loss: 0.0198 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 455/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9919 - loss: 0.0198 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 456/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9919 - loss: 0.0198 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 457/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9919 - loss: 0.0198 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 458/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9919 - loss: 0.0197 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 459/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9919 - loss: 0.0197 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 460/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9919 - loss: 0.0197 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 461/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9919 - loss: 0.0196 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 462/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9919 - loss: 0.0196 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 463/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9919 - loss: 0.0196 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 464/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9919 - loss: 0.0196 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 465/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9919 - loss: 0.0195 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 466/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9919 - loss: 0.0195 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 467/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9919 - loss: 0.0195 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 468/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9919 - loss: 0.0194 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 469/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9919 - loss: 0.0194 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 470/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9919 - loss: 0.0194 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 471/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9919 - loss: 0.0194 - val_accuracy: 1.0000 - val_loss: 0.0044
# Epoch 472/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9919 - loss: 0.0193 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 473/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9919 - loss: 0.0193 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 474/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9919 - loss: 0.0193 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 475/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9919 - loss: 0.0193 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 476/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9919 - loss: 0.0192 - val_accuracy: 1.0000 - val_loss: 0.0043
# Epoch 477/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9919 - loss: 0.0192 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 478/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9919 - loss: 0.0192 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 479/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9919 - loss: 0.0192 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 480/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9919 - loss: 0.0191 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 481/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9919 - loss: 0.0191 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 482/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9919 - loss: 0.0191 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 483/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9919 - loss: 0.0190 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 484/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9919 - loss: 0.0190 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 485/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9919 - loss: 0.0190 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 486/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9919 - loss: 0.0190 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 487/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9919 - loss: 0.0189 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 488/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9919 - loss: 0.0189 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 489/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9919 - loss: 0.0189 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 490/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9919 - loss: 0.0189 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 491/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9919 - loss: 0.0188 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 492/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9919 - loss: 0.0188 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 493/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9919 - loss: 0.0188 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 494/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9919 - loss: 0.0188 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 495/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9919 - loss: 0.0187 - val_accuracy: 1.0000 - val_loss: 0.0040
# Epoch 496/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9919 - loss: 0.0187 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 497/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9919 - loss: 0.0187 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 498/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9919 - loss: 0.0187 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 499/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9919 - loss: 0.0186 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 500/500
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9919 - loss: 0.0186 - val_accuracy: 1.0000 - val_loss: 0.0039

# %%
# Create a figure with two vertically stacked subplots
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(15, 6), sharex=True)

# Plot training and validation loss
ax1.plot(history['loss'], label='Training loss', alpha=.8)
ax1.plot(history['val_loss'], label='Validation loss', alpha=.8)
ax1.set_title('Loss')
ax1.legend()
ax1.grid(alpha=.3)

# Plot training and validation accuracy
ax2.plot(history['accuracy'], label='Training accuracy', alpha=.8)
ax2.plot(history['val_accuracy'], label='Validation accuracy', alpha=.8)
ax2.set_title('Accuracy')
ax2.legend()
ax2.grid(alpha=.3)

# Adjust the layout and display the plot
plt.tight_layout()
plt.subplots_adjust(right=0.85)
plt.show()

# %% [markdown]
# ### 🕹️ Use the Model - Make Inference

# %% [markdown]
# **Binary Classification Metrics**
#
# <img src="https://drive.google.com/uc?export=view&id=1dUVBtRp6yJmfr1-cwUmWtKX2UfgozNaj" width="250"/>
#
# $\text{Accuracy} = \frac{TP + TN}{TP + TN + FP + FN}$
#
# $\text{Precision} = \frac{TP}{TP + FP}$
#
# $\text{Recall} = \frac{TP}{TP + FN}$
#
# $F1 = 2 \cdot \frac{\text{Precision} \cdot \text{Recall}}{\text{Precision} + \text{Recall}}$
#
# &nbsp;
#
# ---
#
# **Multiclass Classification Metrics**
#
# <img src="https://drive.google.com/uc?export=view&id=1yDfrbcjHPTqFx9P5ZPhi07S5XVcXjd6g" width="300"/>
#
# $\text{Accuracy} = \sum_{i=1}^{N} \frac{TP_i}{TP_i + TN_i + FP_i + FN_i}$
#
# $\text{Precision}_i = \frac{TP_i}{TP_i + FP_i}$
#
# $\text{Recall}_i = \frac{TP_i}{TP_i + FN_i}$
#
# $F1_i = 2 \cdot \frac{\text{Precision}_i \cdot \text{Recall}_i}{\text{Precision}_i + \text{Recall}_i}$
#
# &nbsp;
#
# **Macro Averaging**
#
# $\text{Precision}_{macro} = \frac{1}{N} \sum_{i=1}^{N} \text{Precision}_i$
#
# $\text{Recall}_{macro} = \frac{1}{N} \sum_{i=1}^{N} \text{Recall}_i$
#
# $F1_{macro} = \frac{1}{N} \sum_{i=1}^{N} F1_i$
#
# &nbsp;
#
# **Weighted Macro Averaging**
#
# $\text{Precision}_{weighted} = \sum_{i=1}^{N} \left( \frac{N_i}{N} \times \text{Precision}_i \right)$
#
# $\text{Recall}_{weighted} = \sum_{i=1}^{N} \left( \frac{N_i}{N} \times \text{Recall}_i \right)$
#
# $F1_{weighted} = \sum_{i=1}^{N} \left( \frac{N_i}{N} \times F1_i \right)$

# %%
# Load the saved model
model = tfk.models.load_model(f'Penguins_Feedforward_{final_val_accuracy}.keras')

# Display a summary of the model architecture
model.summary(expand_nested=True, show_trainable=True)

# Plot the model architecture
tfk.utils.plot_model(model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)
# Out:
# Model: "FeedforwardNeuralNetwork"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┳━━━━━━━━━┓
# ┃ Layer (type)                        ┃ Output Shape                 ┃       Param # ┃ Traina… ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━╇━━━━━━━━━┩
# │ Input (InputLayer)                  │ (None, 4)                    │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ Hidden (Dense)                      │ (None, 16)                   │            80 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ HiddenActivation (Activation)       │ (None, 16)                   │             0 │    -    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ Output (Dense)                      │ (None, 3)                    │            51 │    Y    │
# ├─────────────────────────────────────┼──────────────────────────────┼───────────────┼─────────┤
# │ Softmax (Activation)                │ (None, 3)                    │             0 │    -    │
# └─────────────────────────────────────┴──────────────────────────────┴───────────────┴─────────┘
#  Total params: 395 (1.55 KB)
#  Trainable params: 131 (524.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 264 (1.04 KB)

# %% [markdown]
# ### 💹 Metrics on the train set, validation set, and finally the test set :

# %%
# Predict class probabilities and get predicted classes
train_predictions = model.predict(X_train, verbose=0)
train_predictions = np.argmax(train_predictions, axis=-1)

# Extract ground truth classes
train_gt = np.argmax(y_train, axis=-1)

# Calculate and display training set accuracy
train_accuracy = accuracy_score(train_gt, train_predictions)
print(f'Accuracy score over the train set: {round(train_accuracy, 4)}')

# Calculate and display training set precision
train_precision = precision_score(train_gt, train_predictions, average='weighted')
print(f'Precision score over the train set: {round(train_precision, 4)}')

# Calculate and display training set recall
train_recall = recall_score(train_gt, train_predictions, average='weighted')
print(f'Recall score over the train set: {round(train_recall, 4)}')

# Calculate and display training set F1 score
train_f1 = f1_score(train_gt, train_predictions, average='weighted')
print(f'F1 score over the train set: {round(train_f1, 4)}')

# Compute the confusion matrix
cm = confusion_matrix(train_gt, train_predictions)

# Create labels combining confusion matrix values
labels = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Plot the confusion matrix with class labels
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=labels, fmt='', xticklabels=['Setosa', 'Versicolor', 'Virginica'], yticklabels=['Setosa', 'Versicolor', 'Virginica'], cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy score over the train set: 0.9966
# Precision score over the train set: 0.9966
# Recall score over the train set: 0.9966
# F1 score over the train set: 0.9966

# %%
# Predict class probabilities and get predicted classes
val_predictions = model.predict(X_val, verbose=0)
val_predictions = np.argmax(val_predictions, axis=-1)

# Extract ground truth classes
val_gt = np.argmax(y_val, axis=-1)

# Calculate and display validation set accuracy
val_accuracy = accuracy_score(val_gt, val_predictions)
print(f'Accuracy score over the validation set: {round(val_accuracy, 4)}')

# Calculate and display validation set precision
val_precision = precision_score(val_gt, val_predictions, average='weighted')
print(f'Precision score over the validation set: {round(val_precision, 4)}')

# Calculate and display validation set recall
val_recall = recall_score(val_gt, val_predictions, average='weighted')
print(f'Recall score over the validation set: {round(val_recall, 4)}')

# Calculate and display validation set F1 score
val_f1 = f1_score(val_gt, val_predictions, average='weighted')
print(f'F1 score over the validation set: {round(val_f1, 4)}')

# Compute the confusion matrix
cm = confusion_matrix(val_gt, val_predictions)

# Create labels combining confusion matrix values
labels = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Plot the confusion matrix with class labels
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=labels, fmt='', xticklabels=['Setosa', 'Versicolor', 'Virginica'], yticklabels=['Setosa', 'Versicolor', 'Virginica'], cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy score over the validation set: 1.0
# Precision score over the validation set: 1.0
# Recall score over the validation set: 1.0
# F1 score over the validation set: 1.0

# %%
# Predict class probabilities and get predicted classes
test_predictions = model.predict(X_test, verbose=0)
test_predictions = np.argmax(test_predictions, axis=-1)

# Extract ground truth classes
test_gt = np.argmax(y_test, axis=-1)

# Calculate and display test set accuracy
test_accuracy = accuracy_score(test_gt, test_predictions)
print(f'Accuracy score over the test set: {round(test_accuracy, 4)}')

# Calculate and display test set precision
test_precision = precision_score(test_gt, test_predictions, average='weighted')
print(f'Precision score over the test set: {round(test_precision, 4)}')

# Calculate and display test set recall
test_recall = recall_score(test_gt, test_predictions, average='weighted')
print(f'Recall score over the test set: {round(test_recall, 4)}')

# Calculate and display test set F1 score
test_f1 = f1_score(test_gt, test_predictions, average='weighted')
print(f'F1 score over the test set: {round(test_f1, 4)}')

# Compute the confusion matrix
cm = confusion_matrix(test_gt, test_predictions)

# Create labels combining confusion matrix values
labels = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Plot the confusion matrix with class labels
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=labels, fmt='', xticklabels=['Setosa', 'Versicolor', 'Virginica'], yticklabels=['Setosa', 'Versicolor', 'Virginica'], cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy score over the test set: 1.0
# Precision score over the test set: 1.0
# Recall score over the test set: 1.0
# F1 score over the test set: 1.0
